# %%
# !pip install -U spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.7.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (25 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.10-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.1.8 (from spacy)
#   Downloading thinc-8.2.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.2-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.4.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.4.0,>=0.1.0 (from spacy)
#   Downloading weasel-0.3.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting typer<0.10.0,>=0.3.0 (from spacy)
#   Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 4.3 MB/s eta 0:00:00
# Collecting smart-open<7.0.0,>=5.2.1 (from spacy)
#   Using cached smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy) (2.31.0)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy)
#   Downloading pydantic-2.5.2-py3-none-any.whl.metadata (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.2/65.2 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy) (23.2)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 4.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.19.0 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy) (1.26.2)
# Collecting annotated-types>=0.4.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.14.5 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading pydantic_core-2.14.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.5 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.11.17)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.1.8->spacy)
#   Downloading blis-0.7.11-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.1.8->spacy)
#   Downloading confection-0.1.4-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Collecting cloudpathlib<0.17.0,>=0.7.0 (from weasel<0.4.0,>=0.1.0->spacy)
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from jinja2->spacy) (2.1.3)
# Downloading spacy-3.7.2-cp311-cp311-macosx_11_0_arm64.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 24.3 MB/s eta 0:00:0031m25.3 MB/s eta 0:00:01
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.8-cp311-cp311-macosx_11_0_arm64.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 4.0 MB/s eta 0:00:00
# Downloading murmurhash-1.0.10-cp311-cp311-macosx_11_0_arm64.whl (26 kB)
# Downloading preshed-3.0.9-cp311-cp311-macosx_11_0_arm64.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.8/128.8 kB 11.4 MB/s eta 0:00:00
# Downloading pydantic-2.5.2-py3-none-any.whl (381 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 18.2 MB/s eta 0:00:00
# Downloading pydantic_core-2.14.5-cp311-cp311-macosx_11_0_arm64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 32.3 MB/s eta 0:00:0031m37.1 MB/s eta 0:00:01
# Using cached smart_open-6.4.0-py3-none-any.whl (57 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp311-cp311-macosx_11_0_arm64.whl (488 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.4/488.4 kB 21.7 MB/s eta 0:00:00
# Downloading thinc-8.2.2-cp311-cp311-macosx_11_0_arm64.whl (778 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.9/778.9 kB 31.5 MB/s eta 0:00:00
# Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Downloading weasel-0.3.4-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 5.6 MB/s eta 0:00:00
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading blis-0.7.11-cp311-cp311-macosx_11_0_arm64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.1 MB/s eta 0:00:0031m31.1 MB/s eta 0:00:01
# Downloading cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 5.2 MB/s eta 0:00:00
# Downloading confection-0.1.4-py3-none-any.whl (35 kB)
# Installing collected packages: cymem, wasabi, typer, spacy-loggers, spacy-legacy, smart-open, pydantic-core, murmurhash, langcodes, cloudpathlib, catalogue, blis, annotated-types, srsly, pydantic, preshed, confection, weasel, thinc, spacy
# Successfully installed annotated-types-0.6.0 blis-0.7.11 catalogue-2.0.10 cloudpathlib-0.16.0 confection-0.1.4 cymem-2.0.8 langcodes-3.3.0 murmurhash-1.0.10 preshed-3.0.9 pydantic-2.5.2 pydantic-core-2.14.5 smart-open-6.4.0 spacy-3.7.2 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.2 typer-0.9.0 wasabi-1.1.2 weasel-0.3.4

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 21.3 MB/s eta 0:00:000:00:01m eta 0:00:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.2)
# Requirement already satisfied: jinja2 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kevinmelchert/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.3)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("en_core_web_sm")

# Process whole documents
text = ("When Sebastian Thrun started working on self-driving cars at "
        "Google in 2007, few people outside of the company took him "
        "seriously. “I can tell you very senior CEOs of major American "
        "car companies would shake my hand and turn away because I wasn’t "
        "worth talking to,” said Thrun, in an interview with Recode earlier "
        "this week.")
doc = nlp(text)

# Analyze syntax
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])

# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# Noun phrases: ['Sebastian Thrun', 'self-driving cars', 'Google', 'few people', 'the company', 'him', 'I', 'you', 'very senior CEOs', 'major American car companies', 'my hand', 'I', 'Thrun', 'an interview', 'Recode']
# Verbs: ['start', 'work', 'drive', 'take', 'tell', 'shake', 'turn', 'talk', 'say']
# Sebastian Thrun PERSON
# Google ORG
# 2007 DATE
# American NORP
# Thrun PERSON
# Recode ORG
# earlier this week DATE

# %%
import pandas as pd
texts = pd.read_csv('../data/rss_fin.csv')

print(texts['title'])

for text in texts.iterrows():
    t = text[1]['text']
    doc = nlp(t)

    # Analyze syntax
    print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
    print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])

    # Find named entities, phrases and concepts
    for entity in doc.ents:
        print(entity.text, entity.label_)
        print('---------------------')
# Out:
# 0      It's the Magnificent Seven's Market. The Other...
# 1      Buy Now, Pay Later Keeps People Spending---Wit...
# 2      How to Make the Most of Your FSA Money Before ...
# 3      Why It's Taking So Long for Americans to Get P...
# 4      Robinhood Woos Wealthier Clients From Bigger B...
#                              ...
# 610        Spirit Airlines Is Almost Cleared for Takeoff
# 611    Could Arbor Realty Trust Slash Its 12.7% Divid...
# 612                  The Real Truth About Interest Rates
# 613             The Federal Reserve’s Aspiring Superhero
# 614         A Surge Could Be Coming for Small Cap Stocks
# Name: title, Length: 615, dtype: object
# Noun phrases: ['Apple', 'Microsoft', 'Alphabet', 'Amazon', 'Nvidia', 'Tesla', 'Meta', 'the other 493 companies', 'the S&amp;P', 'their dust']
# Verbs: ['jump', 'leave']
# Apple ORG
# ---------------------
# Microsoft ORG
# ---------------------
# Alphabet GPE
# ---------------------
# Amazon ORG
# ---------------------
# Nvidia GPE
# ---------------------
# Tesla ORG
# ---------------------
# Meta ORG
# ---------------------
# 75% PERCENT
# ---------------------
# 2023 DATE
# ---------------------
# 493 CARDINAL
# ---------------------
# 500 CARDINAL
# ---------------------
# Noun phrases: ['Consumers', 'installment loans', 'everything', 'holiday gifts', 'groceries', 'laser eye surgery']
# Verbs: ['flock']
# Noun phrases: ['Many workers', 'advantage', 'the tax-free flexible-spending account', 'medical expenses', 'time']
# Verbs: ['take', 'spend', 'help', 'pay', 'run']
# Noun phrases: ['Hundreds', 'banks', 'Fed’s new instant-payment service', 'universal availability']
# Verbs: ['use', 'remain']
# Hundreds CARDINAL
# ---------------------
# Fed ORG
# ---------------------
# years DATE
# ---------------------
# Noun phrases: ['a clientele', 'first-time investors', 'the trading app', 'account transfers', 'it', 'a 1% match']
# Verbs: ['know', 'receive', 'start', 'offer']
# first ORDINAL
# ---------------------
# $1.1 billion MONEY
# ---------------------
# 1% PERCENT
# ---------------------
# Noun phrases: ['driver-assistance features', 'the right way', 'cars', 'the EV pioneer']
# Verbs: ['improve', 'make']
# EV ORG
# ---------------------
# Noun phrases: ['some', 'the major companies', 'whose stocks', 'the week’s news']
# Verbs: ['move']
# week DATE
# ---------------------
# Noun phrases: ['Each', 'the past three years', 'a similarly strong consensus', 'that']
# Verbs: ['have', 'prove']
# the past three years DATE
# ---------------------
# Noun phrases: ['Visa', 'an agreement', 'a majority interest', 'Prosa', 'a payments processor', 'Mexico']
# Verbs: ['enter', 'acquire']
# Visa ORG
# ---------------------
# Prosa GPE
# ---------------------
# Mexico GPE
# ---------------------
# Noun phrases: ['The blue-chip index', 'its third straight record', 'the Federal Reserve', 'the door', 'cuts']
# Verbs: ['notch', 'close', 'open']
# third ORDINAL
# ---------------------
# the week DATE
# ---------------------
# the Federal Reserve ORG
# ---------------------
# Noun phrases: ['Creditors', 'Pimco', 'Davidson Kempner', 'SVB’s roughly $10 billion venture capital business']
# Verbs: ['include', 'wind', 'take']
# Pimco ORG
# ---------------------
# Davidson Kempner PERSON
# ---------------------
# SVB ORG
# ---------------------
# roughly $10 billion MONEY
# ---------------------
# Noun phrases: ['Suitors', 'the $11 billion company', 'private equity and technology firms']
# Verbs: ['include']
# $11 billion MONEY
# ---------------------
# Noun phrases: ['Ricardo Lara', 'climate change', 'a threat', 'California', 'insurers', 'the state']
# Verbs: ['say', 'flee']
# Ricardo Lara PERSON
# ---------------------
# California GPE
# ---------------------
# Noun phrases: ['Falling rates', 'banks’ bond portfolios', 'income', 'higher deposit costs']
# Verbs: ['fall', 'help', 'pressure']
# Noun phrases: ['Chains', 'Circle K', 'Casey', 'General Stores', 'appetizing margins', 'food']
# Verbs: ['see', 'appetize', 'sell']
# Circle K PERSON
# ---------------------
# Casey’s General Stores ORG
# ---------------------
# Noun phrases: ['A slowdown', 'pressure', 'a sector', 'belt-tightening']
# Verbs: ['add', 'face']
# Noun phrases: ['Bonds', 'stocks', 'losses', 'your taxes']
# Verbs: ['gain', 'put', 'work', 'cut']
# this year DATE
# ---------------------
# Noun phrases: ['China’s economic data', 'a mess', 'so strong growth figures', 'November']
# Verbs: ['view']
# China GPE
# ---------------------
# November DATE
# ---------------------
# Noun phrases: ['Companies', 'the grip', 'rare-earth magnets', 'a crucial ingredient', 'modern technology', 'unusual hurdles']
# Verbs: ['try', 'break', 'encounter']
# Noun phrases: ['Two units', 'Blackstone Real Estate Debt Strategies', 'Blackstone Real Estate Income Trust', 'Canada Pension Plan Investment Board', 'funds', 'Rialto Capital', 'a newly formed joint venture', 'the FDIC']
# Verbs: ['affiliate', 'enter', 'form']
# Two CARDINAL
# ---------------------
# Blackstone Real Estate Debt Strategies ORG
# ---------------------
# Blackstone Real Estate Income Trust ORG
# ---------------------
# Rialto Capital ORG
# ---------------------
# FDIC ORG
# ---------------------
# Noun phrases: ['<a href="https://news.google.com/rss/articles/CBMiYmh0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vbmV3cy92aWRlb3MvMjAyMy0xMi0xOC9hc2lhLXhtYXMtMjAyMy1tYWxkaXZpYW4tcHJlc2lkZW50LW1vaGFtZWQtbXVpenp10gEA?oc=5" target="_blank">Watch Asia Xmas']
# Verbs: ['target="_blank">watch']
# 2023 DATE
# ---------------------
# MOHAMED PERSON
# ---------------------
# Noun phrases: ['/CBMiZGh0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vbmV3cy9saXZlLWJsb2cvMjAyMy0xMi0xOC93aGF0LXMtbW92aW5nLXVrLW1hcmtldHMtcmlnaHQtbm93LW1hcmtldHMtdG9kYXnSAQA?oc=5', 'What', 'Moving UK Markets', 'color="#6f6f6f">Bloomberg</font']
# Verbs: ['move']
# target="_blank">FTSE WORK_OF_ART
# ---------------------
# 100 CARDINAL
# ---------------------
# Moving UK Markets ORG
# ---------------------
# Right Now</a>&nbsp;&nbsp;<font ORG
# ---------------------
# Noun phrases: ['<a href="https://news.google.com/rss/articles/CBMiaWh0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vb3Bpbmlvbi9hcnRpY2xlcy8yMDIzLTEyLTE4L2VxdWl0eS1yZXR1cm5zLXBpdm90LXByb2ZpdHMtaGF2ZS1hbHJlYWR5LWJlZW4tbWFkZdIBAA?oc=5" target="_blank">Equity Returns', 'Pivot Profits']
# Verbs: []
# Noun phrases: ['<a href="https://news.google.com/rss/articles/CBMic2h0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vbmV3cy9hcnRpY2xlcy8yMDIzLTEyLTE4L2dvbGRtYW4tcy1rb3N0aW4tbGlmdHMtcy1wLTUwMC1mb3JlY2FzdC1hLW1vbnRoLWFmdGVyLXNldHRpbmctaXTSAQA?oc=5" target="_blank">Goldman\'s Kostin Lifts', '500 Forecast', 'It</a>&nbsp;&nbsp;<font']
# Verbs: ['set']
# Kostin Lifts PERSON
# ---------------------
# 500 CARDINAL
# ---------------------
# Noun phrases: ['<a href="https://news.google.com/rss/articles/CBMicmh0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vbmV3cy9hcnRpY2xlcy8yMDIzLTEyLTE4L2dvbGRtYW4tcmFtcHMtdXAtY3JlZGl0LWJ1c2luZXNzLWluLWluZGlhLXRhcmdldHMtcmljaC1kaWFzcG9yYdIBAA?oc=5" target="_blank">Goldman Ramps Up Credit Business', 'India', 'Diaspora</a>&nbsp;&nbsp;<font']
# Verbs: []
# India GPE
# ---------------------
# Targets Rich ORG
# ---------------------
# Noun phrases: ['Biden’s Security Motorcade', 'Collision', 'Wilmington', 'Delaware</a>&nbsp;&nbsp;<font']
# Verbs: ['involve']
# Biden PERSON
# ---------------------
# Wilmington GPE
# ---------------------
# Noun phrases: ['Hedge Funds', 'See Dollar', 'USD', 'Fed Rate Cut Cut']
# Verbs: ['see', 'weaken']
# Fed Rate Cut Cut ORG
# ---------------------
# Noun phrases: ['Data']
# Verbs: ['signal']
# Noun phrases: ['CBMib2h0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vbmV3cy9hcnRpY2xlcy8yMDIzLTEyLTE3L2Nsb3JveC1ib2VpbmctbWdtLWFuZC1tb3JlLXdoeS1iaWctaGFja3MtaGF2ZS1zdXJnZWQtaW4tMjAyM9IBAA?oc=5', 'target="_blank">Why', 'Big Cybersecurity Hacks', '2023?</a>&nbsp;&nbsp;<font']
# Verbs: ['have', 'surge']
# 2023?</a>&nbsp;&nbsp;<font DATE
# ---------------------
# Noun phrases: ['" target="_blank">Japanese Yen', 'JPY USD', 'Top Currency Pick', 'Huge FX Flop</a>&nbsp;&nbsp;<font', 'color="#6f6f6f">Bloomberg</font']
# Verbs: []
# 2024 DATE
# ---------------------
# Noun phrases: ['<a href="https://news.google.com/rss/articles/CBMiZGh0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vbmV3cy9uZXdzbGV0dGVycy8yMDIzLTEyLTE3L2ZpdmUtdGhpbmdzLXlvdS1uZWVkLXRvLWtub3ctdG8tc3RhcnQteW91ci1kYXnSAQA?oc=5" target="_blank">Five Things', 'You', 'Your Day</a>&nbsp;&nbsp;<font']
# Verbs: ['need', 'know', 'start']
# target="_blank">Five Things You Need to Know to WORK_OF_ART
# ---------------------
# Noun phrases: ['$29 Billion Landbridge Project', 'Bypass Malacca']
# Verbs: ['help']
# $29 Billion MONEY
# ---------------------
# Noun phrases: ['a href="https://news.google.com/rss/articles/CBMib2h0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vbmV3cy9hcnRpY2xlcy8yMDIzLTEyLTE4L3RhaXdhbi1zYXlzLXR3by1jaGluZXNlLWJhbGxvb25zLWNyb3NzZWQta2V5LXNlcGFyYXRpbmctbGluZdIBAA?oc=5" target="_blank">Taiwan', 'Two Chinese Balloons', 'Key Separating Line</a>&nbsp;&nbsp;<font']
# Verbs: ['say', 'cross']
# target="_blank">Taiwan Says WORK_OF_ART
# ---------------------
# Two CARDINAL
# ---------------------
# Chinese NORP
# ---------------------
# Noun phrases: ['IDR USD', 'Indonesia', 'color="#6f6f6f">Bloomberg</font']
# Verbs: ['look', 'weaken']
# IDR ORG
# ---------------------
# Weaken PERSON
# ---------------------
# Indonesia GPE
# ---------------------
# Noun phrases: ['a href="https://news.google.com/rss/articles/CBMiemh0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vbmV3cy9hcnRpY2xlcy8yMDIzLTEyLTE4L21hbGF5c2lhLXMtdG9wLXN0b2NrLXl0bC1wb3dlci1pcy1wb2lzZWQtZm9yLW1vcmUtZ2FpbnMtYWZ0ZXItMjAwLXJhbGx50gEA?oc=5" target="_blank">Malaysia\'s Top Stock', 'More Gains', '200%', 'Rally</a>&nbsp;&nbsp;<font', 'color="#6f6f6f">Bloomberg</font']
# Verbs: ['poise']
# 200% PERCENT
# ---------------------
# Noun phrases: ['Bankruptcy', 'Pay Crypto Creditors']
# Verbs: ['target="_blank">FTX', 'end', 'billions</a>&nbsp;&nbsp;<font']
# Noun phrases: ['<a href="https://news.google.com/rss/articles/CBMicWh0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vbmV3cy9hcnRpY2xlcy8yMDIzLTEyLTE3L2FzaWFuLXN0b2Nrcy1zZXQtZm9yLXNvZnQtb3Blbi1hZnRlci1mZWQtcHVzaGJhY2stbWFya2V0cy13cmFw0gEA?oc=5', 'target="_blank">Stock Market', 'Today', 'Dow', 'S&amp;P Live Updates']
# Verbs: []
# Dec 18</a>&nbsp;&nbsp;<font DATE
# ---------------------
# Noun phrases: ['<a href="https://news.google.com/rss/articles/CBMib2h0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vbmV3cy9hcnRpY2xlcy8yMDIzLTEyLTE3L3plZS1kaXJlY3RvcnMtbG9zZS12b3RlLWFzLWNsb2NrLXRpY2tzLWRvd24tb24tZGVhbC1kZWFkbGluZdIBAA?oc=5', 'Directors', 'Vote', 'Clock', 'Deal']
# Verbs: ['lose', 'tick']
# Noun phrases: ['<a href="https://news.google.com/rss/articles/CBMiemh0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vbmV3cy9hcnRpY2xlcy8yMDIzLTEyLTE3L2Jsb2NrY2hhaW4tYmFzZWQtcHJpdmF0ZS1jcmVkaXQtcmVib3VuZHMtaW4tY3J5cHRvLXdpdGgtNTUtanVtcC1pbi0yMDIz0gEA?oc=5" target="_blank">Blockchain-Based Private Credit Rebounds', 'Crypto', '55% Jump']
# Verbs: ['base']
# 55% PERCENT
# ---------------------
# 2023</a>&nbsp;&nbsp;<font CARDINAL
# ---------------------
# Noun phrases: ['CBMia2h0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vbmV3cy9hcnRpY2xlcy8yMDIzLTEyLTE3L2Jsb29tYmVyZy1uZXdzLWJyaWVmaW5nLWZlZGVyYWwtcmVzZXJ2ZS1zLXAtNTAwLWVhcm5pbmdz0gEA?oc=5', 'Federal Reserve', 'S&amp;P']
# Verbs: []
# target="_blank">Bloomberg News Briefing: Federal Reserve WORK_OF_ART
# ---------------------
# 500 CARDINAL
# ---------------------
# Noun phrases: ["Australia's Link", '$744 Million Deal</a>&nbsp;&nbsp;<font', 'color="#6f6f6f">Bloomberg</font']
# Verbs: ['buy']
# Buy Australia's ORG
# ---------------------
# $744 Million MONEY
# ---------------------
# Noun phrases: ['Commercial Property Loans', '2024</a>&nbsp;&nbsp;<font']
# Verbs: []
# target="_blank">Hong Kong GPE
# ---------------------
# $25 Billion MONEY
# ---------------------
# 2024</a>&nbsp;&nbsp;<font CARDINAL
# ---------------------
# Noun phrases: ['a href="https://news.google.com/rss/articles/CBMibGh0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vbmV3cy9hcnRpY2xlcy8yMDIzLTEyLTE4L2Etcm9kLXMtc2xhbS1zcGFjLWlzLXNhaWQtdG8tcGxhbi1tZXJnZXItd2l0aC1seW5rLWdsb2JhbNIBAA?oc=5" target="_blank">A-Rod\'s Slam SPAC', 'Plan Merger', 'Lynk']
# Verbs: ['say']
# Said PERSON
# ---------------------
# Noun phrases: ['<a href="https://news.google.com/rss/articles/CBMibWh0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vb3Bpbmlvbi9mZWF0dXJlcy8yMDIzLTEyLTE3L21lc3NhZ2UtdG8tbWFnYS10aGUtdXMtbmVlZHMtbW9yZS1mb3JlaWduLWVudGFuZ2xlbWVudHPSAQA?oc=5" target="_blank">Message', 'MAGA', 'The US', 'More Foreign Entanglements</a>&nbsp;&nbsp;<font']
# Verbs: ['need']
# The US Needs More Foreign Entanglements</a>&nbsp;&nbsp;<font ORG
# ---------------------
# Noun phrases: ['a href="https://news.google.com/rss/articles/CBMieGh0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vbmV3cy9hcnRpY2xlcy8yMDIzLTEyLTE3L3dhbGwtc3RyZWV0LXMtcy1wLTUwMC1wcm9maXQtb3V0bG9va3MtaGF2ZW4tdC1idWRnZWQtYXMtd29ybGQtY2hhbmdlc9IBAA?oc=5" target="_blank">Wall Street\'s Profit Outlooks', 'World']
# Verbs: ['budge']
# Noun phrases: ['<a href="https://news.google.com/rss/articles/CBMic2h0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vbmV3cy9hcnRpY2xlcy8yMDIzLTEyLTE3L3doaXRlLWhvdXNlLWNvbmRlbW5zLXRydW1wLXJlbWFya3Mtb24taW1taWdyYXRpb24tYXMtdW4tYW1lcmljYW7SAQA?oc=5', 'House Condemns Trump Remarks', 'Immigration', 'Un', '-', 'American</a>&nbsp;&nbsp;<font']
# Verbs: ['target="_blank">white']
# target="_blank">White House WORK_OF_ART
# ---------------------
# Un ORG
# ---------------------
# Noun phrases: ['Entertainment Seeks Deadline Extension', 'Sony Merger Deal</a>&nbsp;&nbsp;<font']
# Verbs: ['seek']
# Sony ORG
# ---------------------
# Noun phrases: ['target="_blank">Fed\'s Goolsbee', 'Victory', 'color="#6f6f6f">Bloomberg</font']
# Verbs: ['say', 'declare']
# Goolsbee PERSON
# ---------------------
# Noun phrases: ['<a href="https://news.google.com/rss/articles/CBMieWh0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vbmV3cy9hcnRpY2xlcy8yMDIzLTEyLTE3L21hcmF0aG9uLXBldHJvbGV1bS1tcGMtdGV4YXMtY2l0eS1vcmRlcnMtcmVzaWRlbnRzLXRvLXNoZWx0ZXItaW4tcGxhY2XSAQA?oc=5" target="_blank">Marathon Petroleum (MPC): Texas City Lifts Shelter', 'Place</a>&nbsp;&nbsp;<font']
# Verbs: []
# MPC ORG
# ---------------------
# Texas GPE
# ---------------------
# Lifts Shelter PERSON
# ---------------------
# Noun phrases: ['<a href="https://news.google.com/rss/articles/CBMiggFodHRwczovL3d3dy5ibG9vbWJlcmcuY29tL25ld3MvYXJ0aWNsZXMvMjAyMy0xMi0xNy9zaGFsZS1vaWwtcy11bmV4cGVjdGVkLXN1cmdlLXBvc2VzLXRocmVhdC10by1vcGVjLXMtYmlkLXRvLXByb3AtdXAtY3J1ZGUtcHJpY2Vz0gEA?oc=5" target="_blank">Fracking News', 'Shale Oil Surge', 'Threat', "OPEC's Crude"]
# Verbs: ['target="_blank">fracke', 'pose']
# target="_blank">Fracking News: WORK_OF_ART
# ---------------------
# Shale Oil Surge Poses Threat ORG
# ---------------------
# OPEC ORG
# ---------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 8
#       6 for text in texts.iterrows():
#       7     t = text[1]['text']
# ----> 8     doc = nlp(t)
#      10     # Analyze syntax
#      11     print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
#
# File ~/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages/spacy/language.py:1037, in Language.__call__(self, text, disable, component_cfg)
#    1016 def __call__(
#    1017     self,
#    1018     text: Union[str, Doc],
#    (...)
#    1021     component_cfg: Optional[Dict[str, Dict[str, Any]]] = None,
#    1022 ) -> Doc:
#    1023     """Apply the pipeline to some text. The text can span multiple sentences,
#    1024     and can contain arbitrary whitespace. Alignment into the original string
#    1025     is preserved.
#    (...)
#    1035     DOCS: https://spacy.io/api/language#call
#    1036     """
# -> 1037     doc = self._ensure_doc(text)
#    1038     if component_cfg is None:
#    1039         component_cfg = {}
#
# File ~/Spiced-Acadamy/ds-capstone/.venv/lib/python3.11/site-packages/spacy/language.py:1131, in Language._ensure_doc(self, doc_like)
#    1129 if isinstance(doc_like, bytes):
#    1130     return Doc(self.vocab).from_bytes(doc_like)
# -> 1131 raise ValueError(Errors.E1041.format(type=type(doc_like)))
#
# ValueError: [E1041] Expected a string, Doc, or bytes as input, but got: <class 'float'>
