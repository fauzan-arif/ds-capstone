# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense
# Out:
# WARNING:tensorflow:From C:\Users\chris\Documents\1_spicy\000_datadrivendollars\ds-capstone\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
url = 'https://raw.githubusercontent.com/NourozR/Stock-Price-Prediction-LSTM/master/apple_share_price.csv'
df = pd.read_csv(url,usecols=[0,1,2,3,4])
df
# Out:
#            Date    Open    High     Low   Close
# 0     11-Aug-17  156.60  158.57  156.07  157.48
# 1     10-Aug-17  159.90  160.00  154.63  155.32
# 2      9-Aug-17  159.26  161.27  159.11  161.06
# 3      8-Aug-17  158.60  161.83  158.27  160.08
# 4      7-Aug-17  157.06  158.92  156.67  158.81
# ...         ...     ...     ...     ...     ...
# 1659   7-Jan-11   47.71   48.05   47.41   48.02
# 1660   6-Jan-11   47.82   47.89   47.56   47.68
# 1661   5-Jan-11   47.08   47.76   47.07   47.71
# 1662   4-Jan-11   47.49   47.50   46.88   47.33
# 1663   3-Jan-11   46.52   47.18   46.41   47.08
#
# [1664 rows x 5 columns]

# %%
df = df.reindex(index = df.index[::-1]).reset_index(drop=True)
df
# Out:
#            Date    Open    High     Low   Close
# 0      3-Jan-11   46.52   47.18   46.41   47.08
# 1      4-Jan-11   47.49   47.50   46.88   47.33
# 2      5-Jan-11   47.08   47.76   47.07   47.71
# 3      6-Jan-11   47.82   47.89   47.56   47.68
# 4      7-Jan-11   47.71   48.05   47.41   48.02
# ...         ...     ...     ...     ...     ...
# 1659   7-Aug-17  157.06  158.92  156.67  158.81
# 1660   8-Aug-17  158.60  161.83  158.27  160.08
# 1661   9-Aug-17  159.26  161.27  159.11  161.06
# 1662  10-Aug-17  159.90  160.00  154.63  155.32
# 1663  11-Aug-17  156.60  158.57  156.07  157.48
#
# [1664 rows x 5 columns]

# %%
df= df[['Open']]
df.head()
# Out:
#     Open
# 0  46.52
# 1  47.49
# 2  47.08
# 3  47.82
# 4  47.71

# %%
plt.plot(df)

# %%
train_size = int(len(df) * 0.8)
train_data = df.iloc[:train_size]
test_data = df.iloc[train_size:]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train_data)
test_scaled = scaler.transform(test_data)

# %%
def create_sequences(data, input_size):
    X, y = [], []
    for i in range(len(data) - input_size):
        X.append(data[i:i + input_size])
        y.append(data[i + input_size])
    return np.array(X), np.array(y)

input_size = 5
X_train, y_train = create_sequences(train_scaled, input_size)
X_test, y_test = create_sequences(test_scaled, input_size)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (1326, 5, 1)
# (328, 5, 1)

# %%
model = Sequential()
model.add(LSTM(100, activation='relu',input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# Out:
# WARNING:tensorflow:From C:\Users\chris\Documents\1_spicy\000_datadrivendollars\ds-capstone\.venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\chris\Documents\1_spicy\000_datadrivendollars\ds-capstone\.venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=50,validation_split=0.2)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\chris\Documents\1_spicy\000_datadrivendollars\ds-capstone\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 22/22 [==============================] - 1s 11ms/step - loss: 0.0959 - val_loss: 0.0712
# Epoch 2/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0087 - val_loss: 0.0127
# Epoch 3/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 4/50
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.0025
# Epoch 5/50
# 22/22 [==============================] - 0s 4ms/step - loss: 8.0335e-04 - val_loss: 0.0024
# Epoch 6/50
# 22/22 [==============================] - 0s 4ms/step - loss: 6.4390e-04 - val_loss: 0.0013
# Epoch 7/50
# 22/22 [==============================] - 0s 4ms/step - loss: 5.6392e-04 - val_loss: 0.0012
# Epoch 8/50
# 22/22 [==============================] - 0s 4ms/step - loss: 5.4048e-04 - val_loss: 0.0012
# Epoch 9/50
# 22/22 [==============================] - 0s 4ms/step - loss: 5.3810e-04 - val_loss: 0.0011
# Epoch 10/50
# 22/22 [==============================] - 0s 4ms/step - loss: 5.3607e-04 - val_loss: 0.0012
# Epoch 11/50
# 22/22 [==============================] - 0s 5ms/step - loss: 5.3236e-04 - val_loss: 0.0011
# Epoch 12/50
# 22/22 [==============================] - 0s 4ms/step - loss: 5.3400e-04 - val_loss: 0.0012
# Epoch 13/50
# 22/22 [==============================] - 0s 4ms/step - loss: 5.2585e-04 - val_loss: 0.0011
# Epoch 14/50
# 22/22 [==============================] - 0s 4ms/step - loss: 5.4018e-04 - val_loss: 0.0010
# Epoch 15/50
# 22/22 [==============================] - 0s 4ms/step - loss: 5.1856e-04 - val_loss: 0.0011
# Epoch 16/50
# 22/22 [==============================] - 0s 4ms/step - loss: 5.1358e-04 - val_loss: 0.0010
# Epoch 17/50
# 22/22 [==============================] - 0s 4ms/step - loss: 5.0828e-04 - val_loss: 0.0011
# Epoch 18/50
# 22/22 [==============================] - 0s 4ms/step - loss: 5.1766e-04 - val_loss: 9.6103e-04
# Epoch 19/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.9505e-04 - val_loss: 0.0012
# Epoch 20/50
# 22/22 [==============================] - 0s 4ms/step - loss: 5.2330e-04 - val_loss: 0.0010
# Epoch 21/50
# 22/22 [==============================] - 0s 4ms/step - loss: 5.0222e-04 - val_loss: 9.4133e-04
# Epoch 22/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.9726e-04 - val_loss: 0.0011
# Epoch 23/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.9233e-04 - val_loss: 9.6215e-04
# Epoch 24/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.9386e-04 - val_loss: 9.3509e-04
# Epoch 25/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.9557e-04 - val_loss: 0.0011
# Epoch 26/50
# 22/22 [==============================] - 0s 5ms/step - loss: 4.9983e-04 - val_loss: 0.0011
# Epoch 27/50
# 22/22 [==============================] - 0s 5ms/step - loss: 4.7993e-04 - val_loss: 0.0011
# Epoch 28/50
# 22/22 [==============================] - 0s 5ms/step - loss: 4.7151e-04 - val_loss: 8.9907e-04
# Epoch 29/50
# 22/22 [==============================] - 0s 5ms/step - loss: 4.6687e-04 - val_loss: 9.0364e-04
# Epoch 30/50
# 22/22 [==============================] - 0s 4ms/step - loss: 5.1953e-04 - val_loss: 0.0011
# Epoch 31/50
# 22/22 [==============================] - 0s 4ms/step - loss: 5.5982e-04 - val_loss: 9.3545e-04
# Epoch 32/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.5588e-04 - val_loss: 8.9443e-04
# Epoch 33/50
# 22/22 [==============================] - 0s 4ms/step - loss: 5.1354e-04 - val_loss: 9.2646e-04
# Epoch 34/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.8429e-04 - val_loss: 0.0011
# Epoch 35/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.5666e-04 - val_loss: 9.0584e-04
# Epoch 36/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.6139e-04 - val_loss: 9.6097e-04
# Epoch 37/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.6091e-04 - val_loss: 9.5873e-04
# Epoch 38/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.4672e-04 - val_loss: 0.0011
# Epoch 39/50
# 22/22 [==============================] - 0s 5ms/step - loss: 4.5243e-04 - val_loss: 0.0010
# Epoch 40/50
# 22/22 [==============================] - 0s 5ms/step - loss: 4.4311e-04 - val_loss: 8.4830e-04
# Epoch 41/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.4213e-04 - val_loss: 8.5031e-04
# Epoch 42/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.4388e-04 - val_loss: 8.4522e-04
# Epoch 43/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.4646e-04 - val_loss: 8.8007e-04
# Epoch 44/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.5926e-04 - val_loss: 0.0015
# Epoch 45/50
# 22/22 [==============================] - 0s 5ms/step - loss: 4.7617e-04 - val_loss: 8.9905e-04
# Epoch 46/50
# 22/22 [==============================] - 0s 5ms/step - loss: 4.4474e-04 - val_loss: 0.0012
# Epoch 47/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.2524e-04 - val_loss: 8.4662e-04
# Epoch 48/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.3119e-04 - val_loss: 8.0348e-04
# Epoch 49/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.3030e-04 - val_loss: 7.9214e-04
# Epoch 50/50
# 22/22 [==============================] - 0s 4ms/step - loss: 4.1240e-04 - val_loss: 8.1140e-04

# %%
# plot training history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.legend()
plt.show()

# %%
model.save('simple_lstm_stock_model')
# Out:
# INFO:tensorflow:Assets written to: simple_lstm_stock_model\assets
# INFO:tensorflow:Assets written to: simple_lstm_stock_model\assets

# %%
train_predicted = model.predict(X_train.reshape(X_train.shape))
test_predicted = model.predict(X_test.reshape(X_test.shape))

train_predicted = scaler.inverse_transform(train_predicted)
test_predicted = scaler.inverse_transform(test_predicted)

train_actual = scaler.inverse_transform(y_train)
test_actual = scaler.inverse_transform(y_test)

train_rmse = np.sqrt(np.mean((train_actual - train_predicted) ** 2))
test_rmse = np.sqrt(np.mean((test_actual - test_predicted) ** 2))

print("Train RMSE:", train_rmse)
print("Test RMSE:", test_rmse)
# Out:
# 42/42 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 2ms/step
# Train RMSE: 1.9600902187272604
# Test RMSE: 2.6607070193265985

# %%
x1 = np.arange(0, len(train_actual))
x2 = np.arange(len(train_actual), len(train_actual)+len(test_actual))

# %%
plt.plot(x1,train_actual)
plt.plot(x1,train_predicted)
plt.legend(['train_actual','train_predicted'])

# %%
plt.plot(x2,test_actual)
plt.plot(x2,test_predicted)
plt.legend(['test_actual','test_predicted'])

# %%
plt.plot(x1,train_actual)
plt.plot(x1,train_predicted)
plt.plot(x2,test_actual)
plt.plot(x2,test_predicted)
plt.legend(['train_actual','train_predicted','test_actual','test_predicted'])
plt.vlines(x=int(len(train_actual)), color='r',linestyles='dashed', ymin = 0, ymax = max(test_actual))
plt.show()

# %%
future_data = df.iloc[-input_size:]
future_scaled = scaler.transform(future_data)
future_sequence = np.array([future_scaled])

future_predicted = model.predict(future_sequence)
future_predicted = scaler.inverse_transform(future_predicted)

print("Future predicted values:", future_predicted)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# Future predicted values: [[163.77689]]
