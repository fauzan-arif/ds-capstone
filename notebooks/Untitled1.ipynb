# %%
# !pip install stocksent
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 2.3 MB/s eta 0:00:00 0:00:01
# ...
#   Created wheel for stocksent: filename=stocksent-0.4.5-py3-none-any.whl size=30375 sha256=9332f3d4db9b10e12c12bf0765f7a5c65211185b760a1faf767b152c1eee42f9
#   Stored in directory: /Users/ismaildibirov/Library/Caches/pip/wheels/98/f4/09/4eb9cc214babe7bdbea8ec2353aad60d14bef9bcf57a44a22e
# Successfully built stocksent
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense

# Define LSTM model for the first part
def create_lstm_model(input_shape=(10, 1)):
    model = Sequential()

    # Input layer
    model.add(LSTM(50, activation='tanh', input_shape=input_shape, return_sequences=True))
    model.add(Dropout(0.1))

    # Hidden layers
    model.add(LSTM(30, activation='tanh', return_sequences=True))
    model.add(Dropout(0.05))
    model.add(LSTM(20, activation='tanh', return_sequences=True))
    model.add(Dropout(0.01))

    # Output layer
    model.add(LSTM(1, activation='tanh'))

    model.compile(optimizer='adam', loss='mse')

    return model

# Create the LSTM model for the first part
lstm_model = create_lstm_model()

# Print the model summary
lstm_model.summary()

# Define FinBERT model
def create_finbert_model(input_shape=(11, 1)):
    model = Sequential()

    # Input layer
    model.add(LSTM(70, activation='tanh', input_shape=input_shape, return_sequences=True))

    # Hidden layers
    model.add(LSTM(30, activation='tanh', return_sequences=True))
    model.add(LSTM(10, activation='tanh', return_sequences=True))

    # Output layer
    model.add(LSTM(1, activation='tanh'))

    model.compile(optimizer='adam', loss='mse')

    return model

# Create the FinBERT model
finbert_model = create_finbert_model()

# Print the model summary
finbert_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 10, 50)            10400
#
#  dropout (Dropout)           (None, 10, 50)            0
#
#  lstm_1 (LSTM)               (None, 10, 30)            9720
#
#  dropout_1 (Dropout)         (None, 10, 30)            0
#
#  lstm_2 (LSTM)               (None, 10, 20)            4080
#
#  dropout_2 (Dropout)         (None, 10, 20)            0
#
#  lstm_3 (LSTM)               (None, 1)                 88
#
# ...
# Total params: 24288 (94.88 KB)
# Trainable params: 24288 (94.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_4 (LSTM)               (None, 11, 70)            20160
#
# ...
